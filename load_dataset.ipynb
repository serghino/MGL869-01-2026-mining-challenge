# %% [markdown]
# <a href="https://colab.research.google.com/github/serghino/MGL869-01-2026-mining-challenge/blob/main/load_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis AIDEV
#
# Analyse — Analyse du langage utilisé par les agents

# %%
import pandas as pd

# Comments and reviews
pr_comments_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_comments.parquet")
pr_reviews_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_reviews.parquet")
pr_review_comments_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_review_comments_v2.parquet")
# Human-PR
human_pr_df = pd.read_parquet("hf://datasets/hao-li/AIDev/human_pull_request.parquet")
human_pr_task_type_df = pd.read_parquet("hf://datasets/hao-li/AIDev/human_pr_task_type.parquet")

# %%
print(f"len(pr_comments_df): {len(pr_comments_df)}")
print(f"len(pr_reviews_df): {len(pr_reviews_df)}")
print(f"len(pr_review_comments_df): {len(pr_review_comments_df)}")
print(f"len(human_pr_df): {len(human_pr_df)}")
print(f"len(human_pr_task_type_df): {len(human_pr_task_type_df)}")
# Out:
# len(pr_comments_df): 39122
# len(pr_reviews_df): 28875
# len(pr_review_comments_df): 26868
# len(human_pr_df): 6618
# len(human_pr_task_type_df): 6618

# %%
# Étape 1: Explorer la structure des données
print("=== ÉTAPE 1: EXPLORATION DES DONNÉES ===\n")

print("1. Structure de human_pr_df (PRs humaines):")
print(f"   Colonnes: {human_pr_df.columns.tolist()}")
print(f"   Shape: {human_pr_df.shape}")
print(f"\n   Aperçu:")
print(human_pr_df.head(3))

print("\n" + "="*80 + "\n")

print("2. Structure de pr_comments_df:")
print(f"   Colonnes: {pr_comments_df.columns.tolist()}")
print(f"   Shape: {pr_comments_df.shape}")
print(f"\n   Aperçu:")
print(pr_comments_df.head(3))

print("\n" + "="*80 + "\n")

print("3. Structure de pr_reviews_df:")
print(f"   Colonnes: {pr_reviews_df.columns.tolist()}")
print(f"   Shape: {pr_reviews_df.shape}")
print(f"\n   Aperçu:")
print(pr_reviews_df.head(3))

print("\n" + "="*80 + "\n")

print("4. Structure de pr_review_comments_df:")
print(f"   Colonnes: {pr_review_comments_df.columns.tolist()}")
print(f"   Shape: {pr_review_comments_df.shape}")
print(f"\n   Aperçu:")
print(pr_review_comments_df.head(3))
# Out:
# Running cells with '.venv (Python 3.13.1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"/Users/serghinoe/Documents/Personal/Serghino/Canada_Montreal/ETS/L’ingénierie de mise en production des versions logiciel/Projet_Final/.venv/bin/python" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# Mesurer les commentaires des bots vs les humains

# %%
pr_comments_df['text_length'] = pr_comments_df['body'].apply(
    lambda x: len(str(x).split())
)
pr_comments_df.groupby('user_type')['text_length'].mean()
# Out:
# user_type
# Bot     172.071163
# User     57.373655
# Name: text_length, dtype: float64
